# %%
from to_cache import density_fock_overlap

example_file_name = "dsgdb9nsd_077724.xyz"
d,f,o,ch,ee = density_fock_overlap(None, 
    example_file_name,
    cache = "/home/ewachmann/REPOS/Masterarbeit/datasets/QM9/out/c7h10o2_b3lypg_6-31G(2df,p)/pyscf/")

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import SymLogNorm


# Create pcolor plots for d, f, and o
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
log_norm = SymLogNorm(vmin=-10, vmax=10, linthresh=1e-3, linscale=0.3)

# Plot for d
axes[0].pcolor(d.numpy, cmap="bwr", vmin=-1.1, vmax=1.1)#norm=log_norm)
axes[0].set_title('Matrix d')
axes[0].set_xlabel('Columns')
axes[0].set_ylabel('Rows')

# Plot for f
axes[1].pcolor(f.numpy, cmap="bwr", vmin=-1.1, vmax=1.1)#norm=log_norm)
axes[1].set_title('Matrix f')
axes[1].set_xlabel('Columns')
axes[1].set_ylabel('Rows')

# Plot for o
axes[2].pcolor(o.numpy, cmap="bwr", vmin=-1.1, vmax=1.1)#norm=log_norm)
axes[2].set_title('Matrix o')
axes[2].set_xlabel('Columns')
axes[2].set_ylabel('Rows')

# Plot for ch
axes[3].pcolor(ch.numpy, cmap="bwr", vmin=-1.1, vmax=1.1)#norm=log_norm)
axes[3].set_title('Matrix ch')
axes[3].set_xlabel('Columns')
axes[3].set_ylabel('Rows')

print(ee)



plt.tight_layout()
plt.show()
# Out:
# -911.2745821638028
